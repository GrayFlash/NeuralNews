# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
def request(url):
    res = urlopen(url)
    data = res.read()
    soup = BeautifulSoup(data, 'lxml')
    return soup

# %%
urls = ['https://in.reuters.com/news/technology']
ind = ['https://in.reuters.com']

# %%
soup = request(urls[0])
# Out:
# <!--[if !IE]> App Server /produs--i-098a456d4f7be6db4/ <![endif]--><!DOCTYPE html>
# <html lang="en"><head>
# <title>Technology News – News on Mobile, IT, Computers, Information Technology, New Technology</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta charset="utf-8"/><meta content="on" http-equiv="x-dns-prefetch-control"/><link href="//s1.reutersmedia.net" rel="dns-prefetch"/><link href="//s2.reutersmedia.net" rel="dns-prefetch"/><link href="//s3.reutersmedia.net" rel="dns-prefetch"/><link href="//s4.reutersmedia.net" rel="dns-prefetch"/><link href="//static.reuters.com" rel="dns-prefetch"/><link href="//www.googletagservices.com" rel="dns-prefetch"/><link href="//www.googletagmanager.com" rel="dns-prefetch"/><link href="//www.google-analytics.com" rel="dns-prefetch"/><link href="//static.chartbeat.com" rel="dns-prefetch"/><meta content="INDEX, FOLLOW" name="robots"/>
# <!-- Segment -->
# <script>
#   !function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","debug","page","once","off","on"];analytics.factory=function(t){return function(){var e=Array.prototype.slice.call(arguments);e.unshift(t);analytics.push(e);return analytics}};for(var t=0;t<analytics.methods.length;t++){var e=analytics.methods[t];analytics[e]=analytics.factory(e)}analytics.load=function(t){var e=document.createElement("script");e.type="text/javascript";e.async=!0;e.src=("https:"===document.location.protocol?"https://":"http://")+"cdn.segment.com/analytics.js/v1/"+t+"/analytics.min.js";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(e,n)};analytics.SNIPPET_VERSION="4.0.0";
#   analytics.load("IEWBqQ8VWHijTQxb7lEBGFGS9uIJzigZ");
#   }}();
#
#             analytics.ready(function () {
#                 ga('require', 'linker');
#                 ga('linker:autoLink', ['in.mobile.reuters.com']);
#             });
#         </script>
# <!-- Page hiding snippet  -->
# <style>.async-hide { opacity: 0 !important} </style>
# <script>
# (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;
# h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
# (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);
# })(window,document.documentElement,'async-hide','dataLayer',2000,{'GTM-W9SLGS':true});
# </script>
# <!-- Data Layer Object Declaration -->
# <script>window.dataLayer = window.dataLayer || [];</script>
# <!-- New Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(
#     {'gtm.start': new Date().getTime(),event:'gtm.js'}
#     );var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-W9SLGS');</script>
# <!-- End Google Tag Manager -->
# <style>
# @font-face { font-family: 'knowledge-reg'; src: url('//static.reutersmedia.net/resources_v2/fonts/Knowledge-Regular.woff') format('woff'); font-weight: normal; font-style: normal; }
# @font-face { font-family: 'knowledge-light'; src: url('//static.reutersmedia.net/resources_v2/fonts/Knowledge-Light.woff') format('woff'); font-weight: normal; font-style: normal; }
# @font-face { font-family: 'knowledge-medium'; src: url('//static.reutersmedia.net/resources_v2/fonts/Knowledge-Medium.woff') format('woff'); font-weight: normal; font-style: normal; }
# </style><script async="" src="//cdn.adsafeprotected.com/iasPET.1.js"></script></head><body><div class="linebreak"></div>
# <script src="//www.reuters.com/reuters_bootstrap.js" type="text/javascript"></script><script src="//www.reuters.com/reuters_gpt_bootstrap.js" type="text/javascript"></script>
# <script type="text/javascript">var abp;</script><script src="//s4.reutersmedia.net/resources_v2/js/px.js?ch=1" type="text/javascript"></script><script src="//s4.reutersmedia.net/resources_v2/js/px.js?ch=2" type="text/javascript"></script>
# <script type="text/javascript">
# var parallelMediaHosts = new Array();
# parallelMediaHosts.push("s1.reutersmedia.net");parallelMediaHosts.push("s2.reutersmedia.net");parallelMediaHosts.push("s3.reutersmedia.net");parallelMediaHosts.push("s4.reutersmedia.net");</script>
# <meta content="in.reuters/tech/home" name="DCSext.DartZone"/>
# <meta content="Landing - News" name="analyticsAttributes.channel"/>
# <meta content="Landing Page" name="analyticsAttributes.contentType"/>
# <meta content="Technology - Technology" name="analyticsAttributes.contentChannel"/>
# <meta content="Technology" name="analyticsAttributes.topicChannel"/>
# <meta content="Technology" name="analyticsAttributes.topicSubChannel"/>
# <link href="https://in.reuters.com/news/technology" rel="canonical"/>
# <meta content="Reuters Editorial" name="analyticsAttributes.author"/>
# <meta content="https://in.reuters.com/news/technology" name="analyticsAttributes.canonicalUrl"/>
# <meta content="Technology News – News on Mobile, IT, Computers, Information Technology, New Technology" name="analyticsAttributes.contentTitle"/>
# <meta content="IN" name="analyticsAttributes.edition"/>
# <meta content="Reuters Editorial" name="author"/>
# <meta content="Find the New Technology News, updated news on information latest in technology, IT, Computers Technology, mobiles industry, latest IT news online on Reuters India" name="description"/>
# <meta content="technology news,new technology,new technology news,mobile technology ,it news,computers industry news,information technology news,reuters news" name="keywords"/>
# <meta content="technology news;new technology;new technology news;mobile technology ;it news;computers industry news;information technology news;reuters news" name="news_keywords"/>
# <meta content="Find the New Technology News, updated news on information latest in technology, IT, Computers Technology, mobiles industry, latest IT news online on Reuters India" property="og:description"/>
# <meta content="https://s4.reutersmedia.net/resources_v2/images/rcom-default.png" property="og:image"/>
# <meta content="en_IN" property="og:locale"/>
# <meta content="IN" property="og:site_name"/>
# <meta content="Technology News – News on Mobile, IT, Computers, Information Technology, New Technology" property="og:title"/>
# <meta content="section" property="og:type"/>
# <meta content="https://in.reuters.com/news/technology" property="og:url"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Find the New Technology News, updated news on information latest in technology, IT, Computers Technology, mobiles industry, latest IT news online on Reuters India" name="twitter:description"/>
# <meta content="https://s4.reutersmedia.net/resources_v2/images/rcom-default.png" name="twitter:image"/>
# <meta content="Technology News – News on Mobile, IT, Computers, Information Technology, New Technology" name="twitter:title"/>
# <meta content="@ReutersIndia" name="twitter:site"/>
# <meta content="@ReutersIndia" name="twitter:creator"/>
# <script type="application/ld+json">
#     {
#         "@context": "http://schema.org",
#         "@type": "WebPage",
#         "headline": "Technology News – News on Mobile, IT, Computers, Information Technology, New Technology",
#         "url": "https://in.reuters.com/news/technology",
#         "thumbnailUrl": "",
#         "dateCreated": "",
#         "description": "Find the New Technology News, updated news on information latest in technology, IT, Computers Technology, mobiles industry, latest IT news online on Reuters India",
#         "publisher": "Reuters",
#         "creator": [],
#         "keywords": ["technology news","new technology","new technology news","mobile technology ","it news","computers industry news","information technology news","reuters news","Technology"]
#     }
# </script>
# <script>
# if (abp == false || abp == '0'){ adBlocked = '0'; } else { adBlocked = '1'; }
# analytics.page('Technology', {
#     canonical_url: 'https://in.reuters.com/news/technology',
#     content_channel: 'Technology - Technology',
#     content_type: 'Landing Page',
#     content_type_channel: 'Landing - News',
#     edition: 'IN',
#     keywords: 'technology news,new technology,new technology news,mobile technology ,it news,computers industry news,information technology news,reuters news',
#     topic_channel: 'Technology',
#     topic_sub_channel: 'Technology',
#     ad_blocked: adBlocked,
#     platform: 'Desktop',
#     page_view_type: 'Page Load',
#     landing_sponsored: 'false',
#     pageView: '1'
# });
# if (document.referrer.indexOf('/article/') > -1) {
#     analytics.track('article.recirculation', {
#         canonical_url: 'https://in.reuters.com/news/technology',
#         content_channel: 'Technology - Technology',
#         content_type: 'Landing Page',
#         content_type_channel: 'Landing - News',
#         edition: 'IN',
#         keywords: 'technology news,new technology,new technology news,mobile technology ,it news,computers industry news,information technology news,reuters news',
#         topic_channel: 'Technology',
#         topic_sub_channel: 'Technology',
#         ad_blocked: adBlocked,
#         platform: 'Desktop',
#         page_view_type: 'Page Load',
#         landing_sponsored: 'false',
#         pageView: '1',
#         category: 'Article',
#         label: 'Technology',
#         nonInteraction: '0',
#         articleRecirculation: '1'
#     });
# }
# window.article_platform = 'Desktop';
# window.article_edition = 'IN';
# </script>
# <link href="https://s3.reutersmedia.net/resources_v2/images/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://s3.reutersmedia.net/resources_v2/images/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://s1.reutersmedia.net/resources_v2/images/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://s3.reutersmedia.net/resources_v2/images/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="https://s2.reutersmedia.net/resources_v2/css/core.css" rel="stylesheet" type="text/css"/>
# <link href="https://s4.reutersmedia.net/resources_v2/css/core-modules.css" rel="stylesheet" type="text/css"/>
# <link href="https://s3.reutersmedia.net/resources_v2/css/core-in.css" rel="stylesheet" type="text/css"/>
# <script src="https://s3.reutersmedia.net/resources_v2/js/libraries/jquery-2.2.4.min.js" type="text/javascript"></script>
# <style>
# .pageSponsor {
#     position: absolute;
#     top: -10px;
#     right: 0;
#     margin: 0;
# }
# .landing .load-more-content.active{
#     padding: 0 0 8px;
# }
# .landing .load-more-link{
#     margin-bottom: 32px;
# }
# .header.module-header h5.module-desc{
#     font-family: knowledge-reg,helvetica,arial,sans-serif;
# }
#
# .news-headline-list.news-horizontal-overflow article.featured-article .story-photo{
#     width: 100%;
#     float: none;
#     overflow: hidden;
# }
# .news-horizontal-overflow article.story.featured-article{
#     background: #fff;
# }
# .news-headline-list.news-horizontal-overflow article.featured-article .story-photo{
#     opacity: 1;
#     width: 780px;
#     height: 439px;
# }
# .news-horizontal-overflow .story-content {
#     position: absolute;
#     bottom: 0;
#     padding: 0;
#     left: 0px;
#     background: linear-gradient(to top, rgba(0, 0, 0, 0.75) 0, rgba(0, 0, 0, 0) 100%) !important;
#     height: 90px;
#     width: 71%;
# }
# .news-horizontal-overflow .story-content a{
#     color: #fff !important;
#     padding: 0 20px !important;
#     display: block;
# }
# .news-horizontal-overflow .story-content a:hover{
#     color: #f80 !important;
# }
# .news-horizontal-overflow h2.story-title{
#     line-height: 1.05em;
#     font-size: 30px !important;
#     font-family: knowledge-medium, helvetica, arial, sans-serif;
#     font-weight: 400;
# }
# .news-headline-list img{
#     width: 100%;
# }
#
# /* Modules */
# /* Tri */
# .news-horizontal-tri.news-headline-list .story{
#     width: 246px;
#     padding-right: 21px;
# }
# .news-horizontal-tri.news-headline-list .story:last-child{
#     padding-right: 0;
# }
# .news-horizontal-tri.news-headline-list .story .story-photo{
#     width: 246px;
#     height: 164px;
#     margin: 0;
# }
# .news-horizontal-tri.news-headline-list h2.story-title{
#     margin: 16px 0 44px;
#     font-size: 2.2em;
#     font-weight: 500;
#     line-height: 26px;
# }
#
# .news-horizontal-tri.news-headline-list.small h2.story-title,
# .news-horizontal-tri.news-headline-list.small h3.story-title{
#     font-size: 1.8em;
#     line-height: 21px;
#     font-weight: 500;
#     margin: 12px 0;
# }
#
# /* Ad */
# .module-evergreen .gpt-sponsored-mod{
#     position: absolute;
#     right: 12px;
#     top: 2px;
# }
#
# /* Video */
# .video-module .video.featured figure {
#     float: none;
#     width: 300px;
#     height: auto;
#     margin: 0 0 14px 0;
# }
# .video-module .video.featured {
#     float: left;
#     width: 300px;
#     height: auto;
#     margin-left: 0;
#     padding: 0 10px 14px 0;
#     border: none;
# }
# .video-module .video {
#     display: inline-block;
#     width: 300px;
#     margin-left: 0px;
#     padding: 20px 0;
#     border-top: 1px solid #ddd;
# }
#
# .mod-video.mod-video-dark .video-icon,
# .mod-slideshow.mod-slideshow .pictures-icon {
#     position: absolute;
#     top: -37px;
#     left: 0;
# }
# .mod-video.mod-video-dark header.module-header{
#     margin-left: 30px;
# }
#
# /* RSS */
# .mod-rss .story .story-photo{
#     display: none;
# }
# .mod-rss.mod-rss-horizontal .story{
#     padding: 0;
#     float: left;
#     width: 245px;
#     margin-right: 20px;
#     vertical-align: top;
# }
# .mod-rss.mod-rss-horizontal .story:last-child{
#     margin-right: 0;
# }
# .mod-rss.mod-rss-vertical .story{
#     padding: 18px 0;
#     border-bottom: 1px solid #ddd;
# }
# .mod-rss.mod-rss-vertical .story:first-child{
#     padding-top: 0;
# }
#
# /* Legacy */
# .module-table-legacy .leftLabel{
#     background: #f5f5f5;
#     border: none;
#     width: 100%;
#     padding: 10px 0;
#     font-size: 1.2em;
# }
# .module-table-legacy .leftLabel strong{
#     margin-left: 10px;
# }
# .module-table-legacy .leftLabel .dateMenu{
#     margin: 0 10px 0 0;
#     padding: 0;
# }
# .module-table-legacy .leftLabel .reportLinks{
#     padding: 0;
# }
# .module-table-legacy .headerTime{
#     padding: 0;
# }
# .module-table-legacy table{
#     margin-bottom: 24px;
# }
# .module-table-legacy table,
# .module-table-legacy.markets-table td{
#     text-align: left;
#     font-size: 14px;
# }
# .module-table-legacy table th{
#     font-size: 1.2em;
# }
# .module-table-legacy .tabs ul{
#     margin: 0;
#     padding: 0;
# }
# .module-table-legacy .tabs ul li{
#     float: left;
#     list-style: none;
# }
# .module-table-legacy .tabs ul li a {
#     padding: 8px 20px;
#     font-size: 1.4em;
#     text-transform: uppercase;
# }
# .module-table-legacy .tabs ul li.current a,
# .module-table-legacy .tabs ul li a:hover {
#     background: #f5f5f5;
# }
# .module-table-legacy h3 {
#     border-bottom: 1px solid #ff8000;
#     color: #333;
#     font-family: knowledge-light,helvetica,arial,sans-serif;
#     font-weight: 300;
#     font-size: 2.1em;
#     line-height: 1.2em;
#     margin: 0 0 20px 0;
#     padding-bottom: 2px;
#     text-transform: uppercase;
#     position: relative;
# }
# .module-table-legacy .moduleBody .timestamp{
#     margin: 0 0 20px 0;
#     display: inline-block;
#     width: 100%;
# }
# .module-table-legacy .data.changeUp {
#     color: #46AE32;
# }
# .module-table-legacy .data.changeDown{
#     color: #D80A0A;
# }
#
# .module.mod-video.mod-video-dark,
# .module.mod-slideshow.mod-slideshow-dark{
#     display: block;
# }
#
# /* Right Rail*/
# .column2 .news-headline-list article{
#     padding: 18px 0;
#     border-bottom: 1px solid #ddd;
# }
# .column2 .news-headline-list article.featured-article .story-photo{
# 	width: 100%;
#     height: auto;
# }
# .column2 .news-headline-list article .story-photo{
# 	width: 140px;
# 	height: 90px;
# }
# .column2 .news-headline-list .featured-article h3.story-title{
#     font-size: 2.4em;
#     line-height: 26px;
# }
# .column2 .mod-iframe iframe{
#     width: 100%;
# }
# .column2 .news-headline-list ul {
#     margin: 0;
#     padding: 0 0 0 14px;
# }
# .column2 .news-headline-list ul li{
#     color: #666;
#     font-size: 1.4em;
#     line-height: 18px;
# }
#
# /* Video */
# .column2 .video-module .video {
#     padding: 18px 0;
# }
# .column2 .video-module .video.featured{
#     padding: 0 0 18px 0;
# }
# /* Slideshow */
# .column2 .slideshow-container{
#     margin: 0;
# }
# .column2 .slideshow-container .photo-container {
#     width: 100%;
#     padding: 0 0 18px 0;
# }
# .column2 .slideshow-container time.article-time {
#     display: none;
# }
# .column2 .slideshow-container .photo-container img{
#     min-width: auto;
# }
# .column2 .mod-slideshow .photo-container {
#     padding: 18px 0;
#     border-bottom: 1px solid #ddd;
# }
# .column2 .mod-slideshow.mod-slideshow-dark .photo-container{
#     border-bottom: 1px solid #666;
# }
# .column2 .mod-slideshow.mod-slideshow-dark .photo-container:last-child{
#     border: none;
# }
# .column2 .mod-slideshow .photo-container:first-child {
#     padding: 0 0 18px 0;
# }
# .column2 .mod-slideshow .photo-container .photo-thumb{
#     overflow: hidden;
#     float: left;
#     margin: 0 20px 0 0;
#     width: 140px;
#     height: 90px;
#     background-size: 70px;
# }
# .column2 .mod-slideshow .photo-container .photo-thumb img{
#     width: 100%;
# }
#
# .column2 .mod-slideshow .photo-container:first-child .photo-thumb{
#     width: 100%;
#     height: auto;
#     margin: 0 0 10px 0;
#     float: none;
# }
# .column2 .mod-slideshow h3.photo-heading{
#     font-size: 1.8em;
#     margin: 0 0 8px 0;
#     line-height: 21px;
# }
# .column2 .mod-slideshow .slide-blurb{
#     display: none;
# }
# .column2 .mod-slideshow .photo-container:first-child .slide-blurb{
#     display: block;
#     color: #999;
# }
#
#
# /* Markets */
# .column2 #markets-module ul li{
#     list-style: none;
# }
# #markets-module .tabs ul{
#     margin: 0;
#     padding: 0 0 0 8px;
# }
# .column2 #markets-module .tabs ul li{
#     float: left;
#     font-size: 1.3em;
#     font-weight: 800;
#     text-transform: uppercase;
# }
# .column2 #markets-module .tabs ul li span{
#     display: inline-block;
# }
# .column2 #markets-module .module{
#     padding: 0;
# }
# .column2 #markets-module .moreLink {
#     font-size: 1.2em;
#     top: 10px;
# }
#
# /* CMS BUDDY */
# .mod-cmsbuddy .moduleHeader h3{
#     border-bottom: 1px solid #ff8000;
#     color: #333;
#     font-family: knowledge-light,helvetica,arial,sans-serif;
#     font-weight: 300;
#     font-size: 2.1em;
#     line-height: 1.2em;
#     margin: 0 0 18px 0;
#     padding-bottom: 2px;
#     text-transform: uppercase;
#     position: relative;
#     display: block;
# }
# .mod-cmsbuddy .moduleBody h2{
#     font-size: 1.8em;
#     line-height: 21px;
#     display: inline-block;
#     margin-bottom: 6px;
#     font-family: knowledge-medium,helvetica,arial,sans-serif;
#     font-weight: 500;
# }
# .column1 .mod-cmsbuddy .bigStory h2{
#     font-size: 2.4em;
#     line-height: 26px;
# }
# .column2 .mod-cmsbuddy .moduleBody .photo{
#     margin-bottom: 10px;
# }
# .mod-cmsbuddy .moduleBody ul{
#     padding: 0 0 0 15px;
# }
# .mod-cmsbuddy .moduleBody ul li{
#     margin-bottom: 4px;
# }
# .mod-cmsbuddy .moduleBody p,
# .mod-cmsbuddy .moduleBody ul li{
#     color: #666;
#     font-size: 1.4em;
#     line-height: 18px;
#     word-wrap: break-word;
# }
# .mod-cms-buddy .moreLink{
#     display: none;
# }
#
# .column1 .mod-cmsbuddy {
#     padding: 18px 0;
#     border-bottom: 1px solid #ddd;
#     margin-bottom: 18px;
# }
# .column1 .mod-cmsbuddy .module{
#     margin: 0;
#     padding: 0;
# }
#
# .column1 .mod-cmsbuddy .photo{
#     overflow: hidden;
#     float: left;
#     margin: 0 20px 0 0;
#     height: 120px;
#     width: 190px;
# }
# .column1 .mod-cmsbuddy .bigStory .photo{
#     width: 100%;
#     height: auto;
#     clear: both;
# }
# .column1 .mod-cmsbuddy .story-info,
# .column1 .mod-cmsbuddy h2{
#     overflow: hidden;
#     width: 550px;
# }
#
# /* Misc */
# .news-headline-list  #div_gpt_bi_content {
#     border-bottom: 1px solid #ddd;
#     padding: 18px 0;
# }
# .mod-video.mod-video-dark header.module-header h4,
# .mod-slideshow.mod-slideshow-dark header.module-header h4{
# 	color: #fff;
# 	padding-bottom: 10px;
# }
# header.module-header h4.module-heading-lrg a{
# 	background-position: right -264px;
# }
#
# header.module-header h4.module-heading-lrg a:hover{
# 	background-position: right -298px;
# }
#
# .mod-video-full.mod-video.mod-video-dark.mod-video-horizontal .video {
#     width: 252px;
# }
# .mod-video-full.mod-video.mod-video-dark.mod-video-horizontal .video figure {
#     width: 252px;
#     height: 140px;
# }
#
# @media(max-width:1200px) {
#     .news-horizontal-overflow .story-content,
#     .news-headline-list article.featured-article .story-photo,
#     .news-headline-list.news-horizontal-overflow article.featured-article .story-photo {
#         width: 620px !important;
#     }
#     .news-headline-list article.featured-article .story-photo{width:940px;}
#     .column2 .news-headline-list article.featured-article .story-photo{
#         width: 300px !important;
#     }
#     .news-headline-list.news-horizontal-overflow article.featured-article .story-photo{
#         height: 349px !important;
#     }
#     .mod-rss.mod-rss-horizontal .story{
#         width: 183px;
#     }
#     .news-horizontal-tri.news-headline-list .story,
#     .news-horizontal-tri.news-headline-list .story .story-photo{
#         width: 192px;
#     }
#     .news-horizontal-tri.news-headline-list .story .story-photo{
#         height: 128px;
#     }
#     .column1 .module-table-legacy .headerTime{
#         padding: 8px 0;
#         display: inline-block;
#     }
#     .column1 .module-table-legacy .headerTime strong{
#         margin: 0;
#     }
#     .column1 .module-table-legacy.markets-table td{
#         min-width: 90px;
#     }
#     .column1 .mod-cmsbuddy .story-info,
#     .column1 .mod-cmsbuddy h2{
#         width: 410px;
#     }
#     .mod-video-full.mod-video.mod-video-dark.mod-video-horizontal .video{
#         width: 212px;
#     }
#     .mod-video-full.mod-video.mod-video-dark.mod-video-horizontal .video figure {
#         width: 212px;
#         height: 121px;
#     }
# }
# </style><script src="https://s2.reutersmedia.net/resources_v2/js/libraries/cookie.js" type="text/javascript"></script>
# <script src="https://s2.reutersmedia.net/resources_v2/js/core.js" type="text/javascript"></script>
# <script src="https://s2.reutersmedia.net/resources_v2/js/search.js" type="text/javascript"></script>
# <script src="//s4.reutersmedia.net/resources_v2/js/core-most-popular.js" type="text/javascript"></script>
# <script type="text/javascript">
#     if (window.innerWidth <= 481 || navigator.userAgent.match(/Android/i)
#     || navigator.userAgent.match(/webOS/i)
#     || navigator.userAgent.match(/iPhone/i)
#     || navigator.userAgent.match(/iPad/i)
#     || navigator.userAgent.match(/iPod/i)
#     || navigator.userAgent.match(/BlackBerry/i)
#     || navigator.userAgent.match(/Windows Phone/i) ) {
#         if (window.innerWidth == "uk.reuters.com") {
#             document.location = "//uk.mobile.reuters.com/news/technology";
#         } else if (document.location == "in.reuters.com"){
#             document.location = "//in.mobile.reuters.com/news/technology";
#         } else {
#             document.location = "//mobile.reuters.com/news/technology";
#         }
#
#     }
# </script><script type="text/javascript">
#         var _sf_async_config = _sf_async_config || {};
#         _sf_async_config.uid = 52639;
#         _sf_async_config.domain = 'in.reuters.com';
#         _sf_async_config.topStorageDomain = 'reuters.com';
#         _sf_async_config.path = document.querySelector("link[rel='canonical']").getAttribute("href").replace('http://www.', '').replace('https://www.', '');
#         _sf_async_config.flickerControl = false;
#         var _sf_startpt = (new Date()).getTime();
#     </script><script async="" src="//static.chartbeat.com/js/chartbeat_mab.js"></script>
# <!-- New Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-W9SLGS" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <section class="hidden" id="breakingNewsContainer"><div class="group wrap" id="breakingNews"><div class="breaking-content"><div class="breaking-news-type"></div><div class="breaking-news-content"></div></div><div class="close-btn">X</div></div></section>
# <section class="hidden" id="nonEditBannerContainer"><div class="group wrap" id="breakingNews"><div class="breaking-content"><div class="breaking-news-type"></div><div class="breaking-news-content"></div></div><div class="close-btn">X</div></div></section>
# <header id="headerMain">
# <div class="container group">
# <div class="edition-container group">
# <div class="edition-label">Edition:</div>
# <div class="edition-selector">
# <div class="edition">India</div>
# <div class="edition-arrow"></div>
# </div>
# </div>
# <div class="reuters-nav-main">
# <h2 class="reuters-logo">
# <a href="/" title="Reuters"></a>
# </h2>
# </div>
# <div class="utilities" id="utilities"></div>
# </div>
# </header>
# <nav id="headerNav">
# <div class="container group">
# <div class="header-mini-logo">
# <a href="/" title="Reuters"></a>
# </div>
# <ul class="horizontal-list nav-list">
# <li class="nav-item home-tab active-icon no-subnav" id="nav-item-1">
# <a class="nav-link-sec" href="/home">
# <div class="home-icon"></div>
# <span class="text"></span>
# </a>
# </li>
# <li class="nav-item" id="nav-item-2">
# <a class="nav-link-sec" href="/finance">Business</a>
# <div class="subnav" id="subnav-2">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a class="nav-link-subsec" href="/finance">Business Home</a></li>
# <li><a class="nav-link-subsec" href="/finance/economy">Economy</a></li>
# <li><a class="nav-link-subsec" href="/finance/summits">Reuters Summits</a></li>
# <li><a class="nav-link-subsec" href="/finance/deals">Deals</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a class="nav-link-subsec" href="/news/video?videoChannel=104">Business Video</a></li>
# <li><a class="nav-link-subsec" href="/finance/markets/companyOutlooksNews">Company Results &amp; Outlook</a></li>
# <li><a class="nav-link-subsec" href="/subjects/autos">Autos</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item" id="nav-item-3">
# <a class="nav-link-sec" href="/finance/markets">Markets</a>
# <div class="subnav" id="subnav-3">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a class="nav-link-subsec" href="/finance/markets">Markets Home</a></li>
# <li><a class="nav-link-subsec" href="https://in.reuters.com/markets/stocks">Stocks</a></li>
# <li><a class="nav-link-subsec" href="/markets/bonds">Bonds</a></li>
# <li><a class="nav-link-subsec" href="/finance/markets/india-stock-market">India Markets</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a class="nav-link-subsec" href="/finance/markets/us">US Markets</a></li>
# <li><a class="nav-link-subsec" href="/markets/currencies">Currencies</a></li>
# <li><a class="nav-link-subsec" href="/markets/commodities">Commodities</a></li>
# <li><a class="nav-link-subsec" href="https://stockscreener.in.reuters.com/Stock/IN/Index?quickscreen=gaarp">Stock Screener</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a class="nav-link-subsec" href="https://funds.in.reuters.com/IN/screener/screener.asp?reset=1">Fund Screener</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item" id="nav-item-4">
# <a class="nav-link-sec" href="/news/top-news">India</a>
# <div class="subnav" id="subnav-4">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a class="nav-link-subsec" href="/subjects/Kashmir">Kashmir</a></li>
# <li><a class="nav-link-subsec" href="/news/top-news">Top News</a></li>
# <li><a class="nav-link-subsec" href="/subjects/monsoon">Monsoon </a></li>
# <li><a class="nav-link-subsec" href="/news/video/top-news">Top News Video</a></li>
# </ul>
# <ul class="subnav-list">
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item no-subnav" id="nav-item-5">
# <a class="nav-link-sec" href="/news/south-asia">South Asia</a>
# </li>
# <li class="nav-item" id="nav-item-6">
# <a class="nav-link-sec" href="/news/world">World</a>
# <div class="subnav" id="subnav-6">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a class="nav-link-subsec" href="/news/world">World Home</a></li>
# <li><a class="nav-link-subsec" href="/subjects/middle-east">Middle East</a></li>
# <li><a class="nav-link-subsec" href="/subjects/special-reports">Special Reports</a></li>
# <li><a class="nav-link-subsec" href="//www.reuters.com/investigates/">Reuters Investigates</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a class="nav-link-subsec" href="/news/video?videoChannel=117460">World Video</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item active" id="nav-item-7">
# <a class="nav-link-sec" href="/news/technology">Tech</a>
# <div class="subnav" id="subnav-7">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li class="active"><a class="nav-link-subsec" href="/news/technology">Technology Home</a></li>
# <li><a class="nav-link-subsec" href="/news/science">Science</a></li>
# <li><a class="nav-link-subsec" href="/news/video/technology">Tech Video</a></li>
# <li><a class="nav-link-subsec" href="http://www.reuters.com/innovation">Innovation</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a class="nav-link-subsec" href="/energy-environment">Energy and Environment</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item" id="nav-item-8">
# <a class="nav-link-sec" href="/breakingviews">Breakingviews</a>
# <div class="subnav" id="subnav-8">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a class="nav-link-subsec" href="/breakingviews">Breakingviews Home</a></li>
# <li><a class="nav-link-subsec" href="/news/video/breakingviews">Breakingview Videos</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item" id="nav-item-9">
# <a class="nav-link-sec" href="/news/sports">Sport &amp; Life</a>
# <div class="subnav" id="subnav-9">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a class="nav-link-subsec" href="/news/sports">Sports</a></li>
# <li><a class="nav-link-subsec" href="/news/lifestyle">Lifestyle</a></li>
# <li><a class="nav-link-subsec" href="/news/entertainment">Entertainment</a></li>
# <li><a class="nav-link-subsec" href="/news/oddlyEnough">Oddly Enough</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a class="nav-link-subsec" href="/news/health">Health</a></li>
# <li><a class="nav-link-subsec" href="/news/entertainment/arts">Arts</a></li>
# <li><a class="nav-link-subsec" href="/news/video?videoChannel=1004">Lifestyle Video</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item pictures-tab active-icon active-text" id="nav-item-10">
# <a class="nav-link-sec" href="/news/pictures">
# <div class="pictures-icon"></div>
# <span class="text">Pictures</span>
# </a>
# <div class="subnav" id="subnav-10">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a class="nav-link-subsec" href="/news/pictures">Pictures Home</a></li>
# <li><a class="nav-link-subsec" href="http://widerimage.reuters.com">The Wider Image</a></li>
# <li><a class="nav-link-subsec" href="http://widerimage.reuters.com/photographer">Photographers</a></li>
# <li><a class="nav-link-subsec" href="/focus-360">Focus 360</a></li>
# </ul>
# <ul class="subnav-list">
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item video-tab active-icon active-text no-subnav" id="nav-item-11">
# <a class="nav-link-sec" href="/video">
# <div class="video-icon"></div>
# <span class="text">TV</span>
# </a>
# </li>
# <li class="nav-item search-tab active-icon no-subnav"><div class="search-icon"></div></li>
# </ul>
# <div id="searchBar">
# <form action="/search/news" autocomplete="off" class="search-form" id="searchForm" method="get" name="searchbox">
# <input class="search-field" id="searchfield" maxlength="128" name="blob" onfocus="this.value = this.value;" size="30" type="text" value=""/>
# <span class="search-line"></span>
# <input class="search-submit-button" id="search-submit-button" onmousedown="if(document.forms['searchbox'].blob.value == 'Search Reuters') { document.forms['searchbox'].blob.value = ''; }" type="submit" value=""/>
# <div class="search-close-button"></div>
# </form>
# </div>
# </div>
# </nav>
# <div class="nav-white-space"></div>
# <div class="edition-header">
# <div class="container">
# <div class="selection-header"></div>
# <ul class="edition-list">
# <li>
# <div class="item"><a href="//af.reuters.com">Africa</a></div>
# <div class="item"><a class="" href="//lta.reuters.com">América Latina</a></div>
# </li>
# <li>
# <div class="item"><a href="//ara.reuters.com">عربي</a></div>
# <div class="item"><a class="" href="//ar.reuters.com">Argentina</a></div>
# </li>
# <li>
# <div class="item"><a href="//br.reuters.com">Brasil</a></div>
# <div class="item"><a href="//ca.reuters.com">Canada</a></div>
# </li>
# <li>
# <div class="item"><a class="" href="//cn.reuters.com">中国</a></div>
# <div class="item"><a class="" href="//de.reuters.com">Deutschland</a></div>
# </li>
# <li>
# <div class="item"><a href="//es.reuters.com">España</a></div>
# <div class="item"><a href="//fr.reuters.com">France</a></div>
# </li>
# <li>
# <div class="item"><a class="active" href="//in.reuters.com">India</a></div>
# <div class="item"><a href="//it.reuters.com">Italia</a></div>
# </li>
# <li>
# <div class="item"><a class="" href="//jp.reuters.com">日本</a></div>
# <div class="item"><a href="//mx.reuters.com">México</a></div>
# </li>
# <li>
# <div class="item"><a href="//ru.reuters.com">РОССИЯ</a></div>
# <div class="item"><a class="" href="//uk.reuters.com">United Kingdom</a></div>
# </li>
# <li><div class="item"><a class="" href="//www.reuters.com">United States</a></div></li>
# </ul>
# </div>
# </div>
# <div id="content">
# <div id="overlayForSearch"></div>
# <section class="ad-horizontal">
# <div class="group wrap" id="">
# <div class="ad-leaderboard" id="div_gpt_lb"><script>
# gatherAd('div_gpt_lb', [[728, 90],[970,250],[970,180],[970,90],[1,1]], TR3.extractDartZone(), 'no', 'leaderboard');
# </script></div>
# <div class="linebreak"></div>
# </div>
# </section><section>
# <div class="group wrap" id="">
# <header class="module-header">
# <h1 class="module-heading module-heading-page">
#                                     TECHNOLOGY</h1>
# </header>
# <div class="linebreak"></div>
# <div class="pageSponsor"><div id="div_gpt_sponsorlogo"><div class="ad" id="sponsorlogo">
# <script type="text/javascript">
# var dz_final = TR3.extractDartZone();
# // leaderboard
# if( 'sponsorlogo' == 'leaderboard'){
#     //US/UK HOME FASTLANE
#     if((TR3.extractDartZone().indexOf("us.reuters") > -1) || (TR3.extractDartZone().indexOf("uk.reuters") > -1) || (TR3.extractDartZone().indexOf("jp.reuters") > -1) || (TR3.extractDartZone().indexOf("lta.reuters") > -1)){
#         if(typeof(Reuters)!='undefined' && typeof(Reuters.info)!='undefined' && typeof(Reuters.info.channel)!='undefined')
#         {displayAd_sync_fastlane(dz_final,  "storychannel=" + Reuters.info.channel + ";" + adParams2 + "" );}
#         else{ displayAd_sync_fastlane( dz_final, "" + adParams2 + "" ); }
#     }
#     else{
# 		if(typeof(Reuters)!='undefined' && typeof(Reuters.info)!='undefined' && typeof(Reuters.info.channel)!='undefined')
#         { displayAd_sync(dz_final,  "storychannel=" + Reuters.info.channel + ";" + adParams2 + "");}
#         else{ displayAd_sync( dz_final, "" + adParams2 + "" ); }
#     }
# }
# else if('sponsorlogo' == 'mpu'){ googletag.cmd.push(function() { googletag.display('div_gpt_mpu'); }); }
# else if('sponsorlogo' == 'mpu2'){ googletag.cmd.push(function() { googletag.display('div_gpt_mpu2'); }); }
# else if('sponsorlogo' == 'mpulow'){ googletag.cmd.push(function() { googletag.display('div_gpt_mpulow'); }); }
# else if('sponsorlogo' == 'leaderboardcenter'){
#     if((TR3.extractDartZone().indexOf("us.reuters") > -1) || (TR3.extractDartZone().indexOf("uk.reuters") > -1) || (TR3.extractDartZone().indexOf("jp.reuters") > -1)  || (TR3.extractDartZone().indexOf("lta.reuters") > -1)){ googletag.cmd.push(function() { googletag.display('div_gpt_lb_center'); }); }
#     else{ displayAd("div_gpt_sponsorlogo", dz_final,  [250,36], "type=sponsorlogo;" + adParams2 + "" ); }
# }
# else if('sponsorlogo' == 'leaderboardlow'){
#         if((TR3.extractDartZone().indexOf("us.reuters") > -1) || (TR3.extractDartZone().indexOf("uk.reuters") > -1) || (TR3.extractDartZone().indexOf("jp.reuters") > -1) || (TR3.extractDartZone().indexOf("lta.reuters") > -1)){ googletag.cmd.push(function() { googletag.display('div_gpt_lb_low'); }); }
#         else{ displayAd("div_gpt_sponsorlogo", dz_final,  [250,36], "type=sponsorlogo;" + adParams2 + "" ); }
# }
# else{
#     if(typeof(Reuters)!='undefined' && typeof(Reuters.info)!='undefined' && typeof(Reuters.info.channel)!='undefined'){
#         displayAd("div_gpt_sponsorlogo", dz_final,  [250,36], "type=sponsorlogo;storychannel=" + Reuters.info.channel+ ";" + adParams2 + "" );
#     } else{ displayAd("div_gpt_sponsorlogo", dz_final,  [250,36], "type=sponsorlogo;" + adParams2 + "" ); }
# }
# </script>
# </div>
# </div><div class="linebreak"></div>
# </div>
# </div>
# </section><section>
# <div class="group wrap" id="">
# <div class="column1 col col-10">
# <section class="module">
# <section class="module-content">
# <div class="news-headline-list large full-width">
# <article class="story featured-article no-border-bottom">
# <div class="story-photo lazy-photo">
# <a href="/article/usa-tiktok-bytedance-insight/tiktok-troubles-narrow-gap-between-beijing-and-bytedance-founder-zhang-yiming-idINKBN25W0ES">
# <img alt="" border="0" org-src="https://s3.reutersmedia.net/resources/r/?m=02&amp;d=20200905&amp;t=2&amp;i=1532298417&amp;w=1100&amp;fh=&amp;fw=&amp;ll=&amp;pl=&amp;sq=&amp;r=LYNXMPEG8407Q" src="https://s2.reutersmedia.net/resources_v2/images/core-placeholder-featured.png"/>
# </a>
# </div><div class="story-content">
# <a href="/article/usa-tiktok-bytedance-insight/tiktok-troubles-narrow-gap-between-beijing-and-bytedance-founder-zhang-yiming-idINKBN25W0ES">
# <h3 class="story-title">
# 								TikTok troubles narrow gap between Beijing and ByteDance founder Zhang Yiming</h3>
# </a>
# <div class="contributor"></div>
# <p>ByteDance founder Zhang Yiming has long positioned himself as a global internet entrepreneur, largely eschewing Chinese government involvement, but U.S. demands to sell his crown jewel TikTok are testing the boundaries with Beijing.</p>
# <time class="article-time">
# <span class="timestamp">05 Sep 2020</span>
# </time>
# </div>
# </article>
# </div>
# </section>
# </section>
# <section class="module">
# <section class="module-content">
# <div class="news-headline-list">
# <article class="story">
# <div class="story-photo lazy-photo">
# <a href="/article/apple-epic-games/epic-games-asks-court-to-prevent-what-it-describes-as-apples-retaliation-idINKBN25W0HR">
# <img alt="" border="0" org-src="https://s2.reutersmedia.net/resources/r/?m=02&amp;d=20200905&amp;t=2&amp;i=1532303814&amp;w=370&amp;fh=&amp;fw=&amp;ll=&amp;pl=&amp;sq=&amp;r=LYNXMPEG840AE" src="https://s2.reutersmedia.net/resources_v2/images/core-placeholder-featured.png"/>
# </a>
# </div><div class="story-content">
# <a href="/article/apple-epic-games/epic-games-asks-court-to-prevent-what-it-describes-as-apples-retaliation-idINKBN25W0HR">
# <h3 class="story-title">
# 								Epic Games asks court to prevent what it describes as Apple's 'retaliation'</h3>
# </a>
# <div class="contributor"></div>
# <p>Epic Games said late on Friday that it has asked a court to stop what it saw as Apple Inc's retaliation against the "Fortnite" creator after the iPhone maker terminated Epic Games' account on its App Store.</p>
# <time class="article-time">
# <span class="timestamp">05 Sep 2020</span>
# </time>
# </div>
# </article>
# <article class="story">
# <div class="story-photo lazy-photo">
# <a href="/article/czech-gaming/after-covid-delay-world-of-warcraft-comes-to-life-in-a-czech-forest-idINKBN25W0QS">
# <img alt="" border="0" org-src="https://s4.reutersmedia.net/resources/r/?m=02&amp;d=20200905&amp;t=2&amp;i=1532321994&amp;w=370&amp;fh=&amp;fw=&amp;ll=&amp;pl=&amp;sq=&amp;r=LYNXMPEG840HZ" src="https://s2.reutersmedia.net/resources_v2/images/core-placeholder-featured.png"/>
# </a>
# </div><div class="story-content">
# <a href="/article/czech-gaming/after-covid-delay-world-of-warcraft-comes-to-life-in-a-czech-forest-idINKBN25W0QS">
# <h3 class="story-title">
# 								After COVID delay, World of Warcraft comes to life in a Czech forest</h3>
# </a>
# <div class="contributor"></div>
# <p>Czech World of Warcraft fans donned costumes on Saturday to bring the massively popular online game to life, pushing ahead with a scaled-back festival after the coronavirus pandemic postponed the annual event earlier this year.</p>
# <time class="article-time">
# <span class="timestamp">05 Sep 2020</span>
# </time>
# </div>
# </article>
# <article class="story">
# <div class="story-photo">
# <a href="/article/china-space/reusable-chinese-spacecraft-lands-successfully-state-media-idINKBN25X04W">
# <img alt="" border="0" class="placeholder-image" src="https://s2.reutersmedia.net/resources_v2/images/core-placeholder-featured.png"/>
# </a>
# </div><div class="story-content">
# <a href="/article/china-space/reusable-chinese-spacecraft-lands-successfully-state-media-idINKBN25X04W">
# <h3 class="story-title">
# 								Reusable Chinese spacecraft lands successfully - state media</h3>
# </a>
# <div class="contributor"></div>
# <p>An experimental reusable spacecraft launched into orbit two days ago by China has successfully returned to a designated site on Sunday, marking a breakthrough that could lead to cheaper round-trips to space, the official Xinhua News Agency reported.</p>
# <time class="article-time">
# <span class="timestamp">9:37am IST</span>
# </time>
# </div>
# </article>
# <div id="div_gpt_bi_content"></div>
# <article class="story">
# <div class="story-photo lazy-photo">
# <a href="/article/antgroup-ipo-goldman-sachs-exclusive/goldman-sachs-joins-syndicate-for-ant-ipo-of-up-to-30-billion-sources-idINKBN25W098">
# <img alt="" border="0" org-src="https://s1.reutersmedia.net/resources/r/?m=02&amp;d=20200905&amp;t=2&amp;i=1532289435&amp;w=370&amp;fh=&amp;fw=&amp;ll=&amp;pl=&amp;sq=&amp;r=LYNXMPEG84051" src="https://s2.reutersmedia.net/resources_v2/images/core-placeholder-featured.png"/>
# </a>
# </div><div class="story-content">
# <a href="/article/antgroup-ipo-goldman-sachs-exclusive/goldman-sachs-joins-syndicate-for-ant-ipo-of-up-to-30-billion-sources-idINKBN25W098">
# <h3 class="story-title">
# 								Goldman Sachs joins syndicate for Ant IPO of up to $30 billion - sources</h3>
# </a>
# <div class="contributor"></div>
# <p>Goldman Sachs  has joined the growing list of investment banks working on Chinese financial technology firm Ant Group's mammoth initial public offering of up to $30 billion, two people with direct knowledge of the matter said.</p>
# <time class="article-time">
# <span class="timestamp">05 Sep 2020</span>
# </time>
# </div>
# </article>
# <article class="story">
# <div class="story-photo lazy-photo">
# <a href="/article/telecom-it-5g-huawei-tech/tim-ceo-says-not-a-problem-to-develop-5g-without-huawei-idINKBN25W0QM">
# <img alt="" border="0" org-src="https://s3.reutersmedia.net/resources/r/?m=02&amp;d=20200905&amp;t=2&amp;i=1532322328&amp;w=370&amp;fh=&amp;fw=&amp;ll=&amp;pl=&amp;sq=&amp;r=LYNXMPEG840HQ" src="https://s2.reutersmedia.net/resources_v2/images/core-placeholder-featured.png"/>
# </a>
# </div><div class="story-content">
# <a href="/article/telecom-it-5g-huawei-tech/tim-ceo-says-not-a-problem-to-develop-5g-without-huawei-idINKBN25W0QM">
# <h3 class="story-title">
# 								TIM CEO says not a problem to develop 5G without Huawei</h3>
# </a>
# <div class="contributor"></div>
# <p>The head of Telecom Italia said on Saturday the former phone monopoly would have no trouble developing 5G infrastructure in Italy were the government to ban Chinese provider Huawei.</p>
# <time class="article-time">
# <span class="timestamp">05 Sep 2020</span>
# </time>
# </div>
# </article>
# <article class="story">
# <div class="story-photo lazy-photo">
# <a href="/article/microsoft-pentagon-jedi/pentagon-re-evaluation-finds-microsofts-jedi-proposal-still-is-best-idINKBN25W043">
# <img alt="" border="0" org-src="https://s3.reutersmedia.net/resources/r/?m=02&amp;d=20200905&amp;t=2&amp;i=1532282569&amp;w=370&amp;fh=&amp;fw=&amp;ll=&amp;pl=&amp;sq=&amp;r=LYNXMPEG84027" src="https://s2.reutersmedia.net/resources_v2/images/core-placeholder-featured.png"/>
# </a>
# </div><div class="story-content">
# <a href="/article/microsoft-pentagon-jedi/pentagon-re-evaluation-finds-microsofts-jedi-proposal-still-is-best-idINKBN25W043">
# <h3 class="story-title">
# 								Pentagon: Re-evaluation finds Microsoft's JEDI proposal still is best</h3>
# </a>
# <div class="contributor"></div>
# <p>The U.S. Defense Department said on Friday it has completed a comprehensive re-evaluation of its $10 billion JEDI cloud computing contract proposals and determined that Microsoft Corp's  submission still represents the best value for the government.</p>
# <time class="article-time">
# <span class="timestamp">05 Sep 2020</span>
# </time>
# </div>
# </article>
# <article class="story">
# <div class="story-photo">
# <a href="/article/bosnia-tesla/bosnian-tesla-fan-impatient-for-cybertruck-release-builds-a-lookalike-idINKBN25W0O2">
# <img alt="" border="0" class="placeholder-image" src="https://s2.reutersmedia.net/resources_v2/images/core-placeholder-featured.png"/>
# </a>
# </div><div class="story-content">
# <a href="/article/bosnia-tesla/bosnian-tesla-fan-impatient-for-cybertruck-release-builds-a-lookalike-idINKBN25W0O2">
# <h3 class="story-title">
# 								Bosnian Tesla fan impatient for Cybertruck release builds a lookalike</h3>
# </a>
# <div class="contributor"></div>
# <p>A Bosnian fan of both Ford trucks and Elon Musk's Tesla could not just sit on his hands waiting for the electric carmaker to release its Cybertruck, expected from late 2021. Instead he came up with his own version of the futuristic vehicle.</p>
# <time class="article-time">
# <span class="timestamp">05 Sep 2020</span>
# </time>
# </div>
# </article>
# <article class="story">
# <div class="story-photo lazy-photo">
# <a href="/article/global-race-protests-portland-facebook/facebook-removes-pages-of-right-wing-group-patriot-prayer-after-portland-unrest-idINKBN25W04N">
# <img alt="" border="0" org-src="https://s3.reutersmedia.net/resources/r/?m=02&amp;d=20200905&amp;t=2&amp;i=1532283403&amp;w=370&amp;fh=&amp;fw=&amp;ll=&amp;pl=&amp;sq=&amp;r=LYNXMPEG8402J" src="https://s2.reutersmedia.net/resources_v2/images/core-placeholder-featured.png"/>
# </a>
# </div><div class="story-content">
# <a href="/article/global-race-protests-portland-facebook/facebook-removes-pages-of-right-wing-group-patriot-prayer-after-portland-unrest-idINKBN25W04N">
# <h3 class="story-title">
# 								Facebook removes pages of right-wing group Patriot Prayer after Portland unrest</h3>
# </a>
# <div class="contributor"></div>
# <p>Facebook Inc  on Friday removed the pages of U.S. right-wing group Patriot Prayer and its founder Joey Gibson, a company spokesman told Reuters.</p>
# <time class="article-time">
# <span class="timestamp">05 Sep 2020</span>
# </time>
# </div>
# </article>
# <article class="story">
# <div class="story-photo lazy-photo">
# <a href="/article/tesla-index/etsy-gets-into-sp-500-tesla-does-not-idINKBN25W05F">
# <img alt="" border="0" org-src="https://s4.reutersmedia.net/resources/r/?m=02&amp;d=20200905&amp;t=2&amp;i=1532284484&amp;w=370&amp;fh=&amp;fw=&amp;ll=&amp;pl=&amp;sq=&amp;r=LYNXMPEG8402U" src="https://s2.reutersmedia.net/resources_v2/images/core-placeholder-featured.png"/>
# </a>
# </div><div class="story-content">
# <a href="/article/tesla-index/etsy-gets-into-sp-500-tesla-does-not-idINKBN25W05F">
# <h3 class="story-title">
# 								Etsy gets into S&amp;P 500, Tesla does not</h3>
# </a>
# <div class="contributor"></div>
# <p>Shares of Tesla  tumbled 7% in extended trade on Friday after the electric car maker was excluded from a group of companies being added to the S&amp;P 500, among them Etsy, whose stock market value is less than a 20th of Tesla's.</p>
# <time class="article-time">
# <span class="timestamp">05 Sep 2020</span>
# </time>
# </div>
# </article>
# </div>
# </section>
# </section>
# <div class="control-nav">
# <a class="control-nav-next" href="/news/archive/technologynews?view=page&amp;page=2&amp;pageSize=10">
# 						View More<i class="page-arrow page-arrow-right"></i>
# </a>
# </div>
# <div id="div_gpt_bi_content"><div class="ad" id="bi_content">
# <script type="text/javascript">
# var dz_final = TR3.extractDartZone();
# // leaderboard
# if( 'bi_content' == 'leaderboard'){
#     //US/UK HOME FASTLANE
#     if((TR3.extractDartZone().indexOf("us.reuters") > -1) || (TR3.extractDartZone().indexOf("uk.reuters") > -1) || (TR3.extractDartZone().indexOf("jp.reuters") > -1) || (TR3.extractDartZone().indexOf("lta.reuters") > -1)){
#         if(typeof(Reuters)!='undefined' && typeof(Reuters.info)!='undefined' && typeof(Reuters.info.channel)!='undefined')
#         {displayAd_sync_fastlane(dz_final,  "storychannel=" + Reuters.info.channel + ";" + adParams2 + "" );}
#         else{ displayAd_sync_fastlane( dz_final, "" + adParams2 + "" ); }
#     }
#     else{
# 		if(typeof(Reuters)!='undefined' && typeof(Reuters.info)!='undefined' && typeof(Reuters.info.channel)!='undefined')
#         { displayAd_sync(dz_final,  "storychannel=" + Reuters.info.channel + ";" + adParams2 + "");}
#         else{ displayAd_sync( dz_final, "" + adParams2 + "" ); }
#     }
# }
# else if('bi_content' == 'mpu'){ googletag.cmd.push(function() { googletag.display('div_gpt_mpu'); }); }
# else if('bi_content' == 'mpu2'){ googletag.cmd.push(function() { googletag.display('div_gpt_mpu2'); }); }
# else if('bi_content' == 'mpulow'){ googletag.cmd.push(function() { googletag.display('div_gpt_mpulow'); }); }
# else if('bi_content' == 'leaderboardcenter'){
#     if((TR3.extractDartZone().indexOf("us.reuters") > -1) || (TR3.extractDartZone().indexOf("uk.reuters") > -1) || (TR3.extractDartZone().indexOf("jp.reuters") > -1)  || (TR3.extractDartZone().indexOf("lta.reuters") > -1)){ googletag.cmd.push(function() { googletag.display('div_gpt_lb_center'); }); }
#     else{ displayAd("div_gpt_bi_content", dz_final, [[780,156],[1,1]], "type=bi_content;" + adParams2 + "" ); }
# }
# else if('bi_content' == 'leaderboardlow'){
#         if((TR3.extractDartZone().indexOf("us.reuters") > -1) || (TR3.extractDartZone().indexOf("uk.reuters") > -1) || (TR3.extractDartZone().indexOf("jp.reuters") > -1) || (TR3.extractDartZone().indexOf("lta.reuters") > -1)){ googletag.cmd.push(function() { googletag.display('div_gpt_lb_low'); }); }
#         else{ displayAd("div_gpt_bi_content", dz_final, [[780,156],[1,1]], "type=bi_content;" + adParams2 + "" ); }
# }
# else{
#     if(typeof(Reuters)!='undefined' && typeof(Reuters.info)!='undefined' && typeof(Reuters.info.channel)!='undefined'){
#         displayAd("div_gpt_bi_content", dz_final, [[780,156],[1,1]], "type=bi_content;storychannel=" + Reuters.info.channel+ ";" + adParams2 + "" );
#     } else{ displayAd("div_gpt_bi_content", dz_final, [[780,156],[1,1]], "type=bi_content;" + adParams2 + "" ); }
# }
# </script>
# </div>
# </div><div class="linebreak"></div>
# <div class="linebreak"></div>
# </div>
# <div class="column2 col col-4">
# <div class="sticky-1"><div id="div_gpt_mpu"><script>
# gatherAd('div_gpt_mpu', [[300,250],[1,1],[300,600],[300,1050],[160,600],[120,600]], TR3.extractDartZone(), 'no', 'mpu');
# </script></div>
# </div><section class="module mod-video mod-video-dark">
# <header class="module-header">
# <h4 class="module-heading">
# 					Technology <span class="title-last">Video</span>
# </h4>
# </header>
# <section class="module-content">
# <i class="video-icon"></i><div class="video-module">
# <div class="video group">
# <a href="/video/2020/09/04/doj-to-file-google-lawsuit-in-weeks-sour?videoId=718594359&amp;videoChannel=105"><figure>
# <img alt="DOJ to file Google lawsuit in weeks -sources" border="0" src="https://s3.reutersmedia.net/resources/r/?d=20200904&amp;i=OVCUA4497&amp;w=&amp;r=OVCUA4497&amp;t=2"/>
# <span class="slide-length"><i class="video-indicator"></i>01:41</span></figure></a>
# <div class="video-header">
# <h3 class="video-heading">
# <a href="/video/2020/09/04/doj-to-file-google-lawsuit-in-weeks-sour?videoId=718594359&amp;videoChannel=105">DOJ to file Google lawsuit in weeks -sources</a>
# </h3>
# </div>
# </div>
# <div class="video group">
# <a href="/video/2020/08/28/cryptosphere-the-freewheeling-world-of-c?videoId=718205894&amp;videoChannel=105"><figure>
# <img alt="Cryptosphere: The freewheeling world of crypto lending" border="0" src="https://s4.reutersmedia.net/resources/r/?d=20200828&amp;i=RCV008NUU&amp;w=&amp;r=RCV008NUU&amp;t=2"/>
# <span class="slide-length"><i class="video-indicator"></i>01:46</span></figure></a>
# <div class="video-header">
# <h3 class="video-heading">
# <a href="/video/2020/08/28/cryptosphere-the-freewheeling-world-of-c?videoId=718205894&amp;videoChannel=105">Cryptosphere: The freewheeling world of crypto lending</a>
# </h3>
# </div>
# </div>
# <div class="video group">
# <a href="/video/2020/08/20/autonomous-aircraft-takes-off?videoId=717727982&amp;videoChannel=105"><figure>
# <img alt="Autonomous aircraft takes off" border="0" src="https://s4.reutersmedia.net/resources/r/?d=20200820&amp;i=OVCS26Q8R&amp;w=&amp;r=OVCS26Q8R&amp;t=2"/>
# <span class="slide-length"><i class="video-indicator"></i>02:09</span></figure></a>
# <div class="video-header">
# <h3 class="video-heading">
# <a href="/video/2020/08/20/autonomous-aircraft-takes-off?videoId=717727982&amp;videoChannel=105">Autonomous aircraft takes off</a>
# </h3>
# </div>
# </div>
# <div class="video group">
# <a href="/video/2020/08/17/us-again-tightens-restrictions-on-huawei?videoId=717530842&amp;videoChannel=105"><figure>
# <img alt="U.S. again tightens restrictions on Huawei" border="0" src="https://s3.reutersmedia.net/resources/r/?d=20200817&amp;i=OVCRN7OUJ&amp;w=&amp;r=OVCRN7OUJ&amp;t=2"/>
# <span class="slide-length"><i class="video-indicator"></i>01:23</span></figure></a>
# <div class="video-header">
# <h3 class="video-heading">
# <a href="/video/2020/08/17/us-again-tightens-restrictions-on-huawei?videoId=717530842&amp;videoChannel=105">U.S. again tightens restrictions on Huawei</a>
# </h3>
# </div>
# </div>
# <div class="video group">
# <a href="/video/2020/08/17/germany-probes-amazon-over-price-control?videoId=717518307&amp;videoChannel=105"><figure>
# <img alt="Germany probes Amazon over price controls - FAZ" border="0" src="https://s2.reutersmedia.net/resources/r/?d=20200817&amp;i=OVCRN7JBF&amp;w=&amp;r=OVCRN7JBF&amp;t=2"/>
# <span class="slide-length"><i class="video-indicator"></i>01:27</span></figure></a>
# <div class="video-header">
# <h3 class="video-heading">
# <a href="/video/2020/08/17/germany-probes-amazon-over-price-control?videoId=717518307&amp;videoChannel=105">Germany probes Amazon over price controls - FAZ</a>
# </h3>
# </div>
# </div>
# </div>
# </section>
# </section>
# <div class="sticky-1"><div id="div_gpt_mpulow"><script>
# gatherAd('div_gpt_mpulow', [[300, 250],[300,600],[1,1]], TR3.extractDartZone(), 'no', 'mpulow');
# </script></div>
# </div></div>
# </div>
# </section></div>
# <footer>
# <section class="footer">
# <div class="group wrap" id="">
# <script>
#
# callAds();
# </script>
# <div id="section-follow-buttons"><span class="footer-follow">Follow Reuters: </span>
# <ul>
# <li id="foot-twitter"><a href="//twitter.com/ReutersIndia" target="_blank"><span class="follow-button follow-twitter">Follow Us On Twitter</span></a></li>
# <li id="foot-facebook"><a href="//www.facebook.com/india.reuters/" target="_blank"><span class="follow-button follow-facebook">Follow Us On Facebook</span></a></li>
# <li id="foot-linkedin"><a href="//www.linkedin.com/company/10256858/" target="_blank"><span class="follow-button follow-linkedin">Follow Us On LinkedIn</span></a></li>
# </ul></div><div class="footer-more-links"><span>
# <span class="footer-more">Subscribe: </span>
# <a href="//newslink.in.reuters.com/join/subscribe">Newsletters</a>  | <a href="//in.reuters.com/tools/mobile">Apps</a>
# </span></div></div>
# </section><section class="footer-body">
# <div class="group wrap" id="">
# <div class="footer-services-link"><a href="//sales.reuters.com/en" target="_blank">Advertise with Us</a> | <a href="//www.reutersagency.com?utm_source=website&amp;utm_medium=reuters&amp;utm_campaign=site-referral&amp;utm_content=india&amp;utm_term=0">Reuters News Agency</a> |  <a href="//www.reutersagency.com/en/about/brand-attribution-guidelines">Brand Attribution Guidelines</a>  | <a href="//thomsonreuters.com/en/careers.html" target="_blank">Careers</a> | <a href="/article/us-reuters-editorial-leadership/reuters-editorial-leadership-idUSKBN1KE2SD" target="_blank">Reuters Editorial Leadership</a>
# </div><div class="disclaimer"><div class="footer-summary">
# <p>Reuters, the news and media division of <a href="//thomsonreuters.com/" target="_blank">Thomson Reuters</a>, is the world’s largest international multimedia news provider reaching more than one billion people every day. Reuters provides trusted business, financial, national, and international news to professionals via Thomson Reuters desktops, the world's media organizations, and directly to consumers at Reuters.com and via Reuters TV.  Learn more about Thomson Reuters products:</p>
# </div>
# </div><div class="product-container">
# <a href="https://www.refinitiv.com/en/products/eikon-trading-software" target="_blank">
# <div class="product">
# <div class="prod-title">Eikon</div>
# <div class="prod-content">Information, analytics and exclusive news on financial markets - delivered in an
#                 intuitive desktop and mobile interface </div>
# </div>
# </a>
# <a href="https://www.refinitiv.com/en/products/elektron-enterprise-data-management" target="_blank">
# <div class="product">
# <div class="prod-title">Elektron</div>
# <div class="prod-content">Everything you need to empower your workflow and enhance your enterprise data
#                 management </div>
# </div>
# </a>
# <a href="https://www.refinitiv.com/en/products/world-check-kyc-screening" target="_blank">
# <div class="product">
# <div class="prod-title">World-Check</div>
# <div class="prod-content">Screen for heightened risk individual and entities globally to help uncover hidden risks in business relationships and human networks
#       </div>
# </div>
# </a>
# <a href="//legalsolutions.thomsonreuters.com/law-products/westlaw-legal-research/" target="_blank">
# <div class="product">
# <div class="prod-title">Westlaw</div>
# <div class="prod-content">Build the strongest argument relying on authoritative content, attorney-editor expertise, and industry defining technology
#       </div>
# </div>
# </a>
# <a href="//tax.thomsonreuters.com/products/brands/onesource/" target="_blank">
# <div class="product">
# <div class="prod-title">ONESOURCE</div>
# <div class="prod-content">The most comprehensive solution to manage all your complex and ever-expanding tax and compliance needs
#       </div>
# </div>
# </a>
# <a href="//tax.thomsonreuters.com/products/brands/checkpoint/" target="_blank">
# <div class="product prod-last">
# <div class="prod-title">CHECKPOINT</div>
# <div class="prod-content">The industry leader for online information for tax, accounting and finance professionals
#       </div>
# </div>
# </a>
# </div><div class="linebreak"></div>
# <div class="footer-policy-links"><p> All quotes delayed a minimum of 15 minutes. <a href="/info/disclaimer">See here for a complete list</a> of exchanges and delays. </p>
# <div class="footer-policies">
# <ul><li class="h-links">
# <div class="reuters-copyright">
# <script type="text/javascript">
#             var year = new Date();
#             document.write('<a href="//www.thomsonreuters.com/en/policies/copyright.html">&copy;  ' + year.getFullYear() + ' Reuters. All Rights Reserved.</a>');
#         </script>
# </div>
# </li>
# <li class="h-links"><a href="//reuters.zendesk.com/" target="_blank">Site Feedback</a></li>
# <li class="h-links"><a href="https://reuters.zendesk.com/anonymous_requests/new" target="_blank">Corrections</a></li>
# <li class="h-links"><a href="//advertising-guidelines"> Advertising Guidelines</a></li>
# <li class="h-links"><a href="//info.evidon.com/pub_info/15802" target="_blank">Cookies</a></li>
# <li class="h-links"><a href="//in.reuters.com/terms-of-use" target="_blank">Terms of Use</a></li>
# <li class="h-links"><a href="https://www.thomsonreuters.com/en/privacy-statement.html" target="_blank">Privacy Policy</a></li>
# <li class="h-links h-links-last"><a href="javascript:window.evidon.notice.showOptions();">Do Not Sell My Personal Information</a></li>
# </ul>
# </div></div></div>
# </section>
# </footer>
# <script src="https://s4.reutersmedia.net/resources_v2/js/core-header.js" type="text/javascript"></script>
# <script src="https://s3.reutersmedia.net/resources_v2/js/core-login.js" type="text/javascript"></script>
# <script src="https://s2.reutersmedia.net/resources_v2/js/core-tracking.js" type="text/javascript"></script>
# <script src="https://s2.reutersmedia.net/resources_v2/js/rcom-social-share.js" type="text/javascript"></script>
# <script src="https://s2.reutersmedia.net/resources_v2/js/libraries/core-lib.js" type="text/javascript"></script>
# <script src="https://s4.reutersmedia.net/resources_v2/js/core-modules.js" type="text/javascript"></script>
# <script language="javascript" src="//www.reuters.com/reuters_gpt_bootstrap_footer.js" type="text/javascript"></script>
# <section>
# <div class="group" id="">
# <script type="text/javascript">
#     var _sf_startpt = (new Date()).getTime();
#     var _sf_async_config = _sf_async_config || {};
#
#     _sf_async_config.playerdomain = 'queso-cdn.prod.reuters.tv';
#     _sf_async_config.sections = 'Technology';
#     _sf_async_config.autoDetect = false;
#
#     _sf_async_config.authors = 'Reuters Editorial';
#     _sf_async_config.type = 'Landing Page';
#
#     (function(){
#       function loadChartbeat() {
#         window._sf_endpt=(new Date()).getTime();
#         var e = document.createElement('script');
#         e.setAttribute('language', 'javascript');
#         e.setAttribute('type', 'text/javascript');
#         e.setAttribute('src', '//static.chartbeat.com/js/chartbeat_video.js');
#         document.body.appendChild(e);
#       }
#       var oldonload = window.onload;
#       window.onload = (typeof window.onload != 'function') ?
#          loadChartbeat : function() { oldonload(); loadChartbeat(); };
#     })();
#   </script>
# <script src="//s4.reutersmedia.net/resources_v2/js/core-rage.js" type="text/javascript"></script><div class="linebreak"></div>
# <script src="//s4.reutersmedia.net/resources_v2/js/core-rivet.js" type="text/javascript"></script><div class="linebreak"></div>
# </div>
# </section>
# <script type="text/javascript">
# </script>
# </body></html>

# %%
articles_tab = soup.find_all('article',{'class':'story'})

li = []

for article in articles_tab:
    image_url = article.find('img')['src']
    story = article.find('div',{'class':'story-content'})
    url_s = ind[0] + story.find('a')['href']
    headlines = (story.find('h3').text).strip(' ')
    brief = (story.find('p').text)
    soup2 = request(url_s)
    paras = soup2.find_all('p',{'class':'Paragraph-paragraph-2Bgue ArticleBody-para-TD_9x'})
    
    st = ''
    for P in paras:
        st = st + P.text +  '\n'
    #articles_list.append([title, story_url, brief, para, images])
    li.append([headlines, url_s, brief, st, image_url])

# %%
df = pd.DataFrame(li, columns=['Title', 'Story Url', 'Brief Intro', 'Paragraph', 'Image Url'])

# %%
df
# Out:
#                                                Title  \
# 0  \n\t\t\t\t\t\t\t\tTikTok troubles narrow gap b...
# 1  \n\t\t\t\t\t\t\t\tEpic Games asks court to pre...
# 2  \n\t\t\t\t\t\t\t\tAfter COVID delay, World of ...
# 3  \n\t\t\t\t\t\t\t\tReusable Chinese spacecraft ...
# 4  \n\t\t\t\t\t\t\t\tGoldman Sachs joins syndicat...
# 5  \n\t\t\t\t\t\t\t\tTIM CEO says not a problem t...
# 6  \n\t\t\t\t\t\t\t\tPentagon: Re-evaluation find...
# 7  \n\t\t\t\t\t\t\t\tBosnian Tesla fan impatient ...
# 8  \n\t\t\t\t\t\t\t\tFacebook removes pages of ri...
# 9  \n\t\t\t\t\t\t\t\tEtsy gets into S&P 500, Tesl...
#
#                                            Story Url  \
# 0  https://in.reuters.com/article/usa-tiktok-byte...
# 1  https://in.reuters.com/article/apple-epic-game...
# 2  https://in.reuters.com/article/czech-gaming/af...
# 3  https://in.reuters.com/article/china-space/reu...
# 4  https://in.reuters.com/article/antgroup-ipo-go...
# 5  https://in.reuters.com/article/telecom-it-5g-h...
# 6  https://in.reuters.com/article/microsoft-penta...
# 7  https://in.reuters.com/article/bosnia-tesla/bo...
# 8  https://in.reuters.com/article/global-race-pro...
# 9  https://in.reuters.com/article/tesla-index/ets...
#
#                                          Brief Intro  \
# 0  ByteDance founder Zhang Yiming has long positi...
# 1  Epic Games said late on Friday that it has ask...
# 2  Czech World of Warcraft fans donned costumes o...
# 3  An experimental reusable spacecraft launched i...
# 4  Goldman Sachs  has joined the growing list of ...
# 5  The head of Telecom Italia said on Saturday th...
# 6  The U.S. Defense Department said on Friday it ...
# 7  A Bosnian fan of both Ford trucks and Elon Mus...
# 8  Facebook Inc  on Friday removed the pages of U...
# 9  Shares of Tesla  tumbled 7% in extended trade ...
#
#                                            Paragraph  \
# 0  BEIJING/HONG KONG (Reuters) - ByteDance founde...
# 1  (Reuters) - Epic Games said late on Friday tha...
# 2  KAMYK NAD VLTAVOU, Czech Republic (Reuters) - ...
# 3  BEIJING (Reuters) - An experimental reusable s...
# 4  HONG KONG (Reuters) - Goldman Sachs GS.N has j...
# 5  CERNOBBIO, Italy (Reuters) - The head of Telec...
# 6  WASHINGTON (Reuters) - The U.S. Defense Depart...
# 7  MOSTAR, Bosnia (Reuters) - A Bosnian fan of bo...
# 8  SAN FRANCISCO (Reuters) - Facebook Inc FB.O on...
# 9  (Reuters) - Shares of Tesla TSLA.O tumbled 7% ...
#
#                                            Image Url
# 0  https://s2.reutersmedia.net/resources_v2/image...
# 1  https://s2.reutersmedia.net/resources_v2/image...
# 2  https://s2.reutersmedia.net/resources_v2/image...
# 3  https://s2.reutersmedia.net/resources_v2/image...
# 4  https://s2.reutersmedia.net/resources_v2/image...
# 5  https://s2.reutersmedia.net/resources_v2/image...
# 6  https://s2.reutersmedia.net/resources_v2/image...
# 7  https://s2.reutersmedia.net/resources_v2/image...
# 8  https://s2.reutersmedia.net/resources_v2/image...
# 9  https://s2.reutersmedia.net/resources_v2/image...

# %%
df.to_csv('ThirdSetArticles.csv', index=False)
